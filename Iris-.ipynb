# %%
#importing dataset
import pandas as pd
f=pd.read_csv('iris.csv')
f
# Out:
#      sepal_length  sepal_width  petal_length  petal_width         species
# 0             5.1          3.5           1.4          0.2     Iris-setosa
# 1             4.9          3.0           1.4          0.2     Iris-setosa
# 2             4.7          3.2           1.3          0.2     Iris-setosa
# 3             4.6          3.1           1.5          0.2     Iris-setosa
# 4             5.0          3.6           1.4          0.2     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 145           6.7          3.0           5.2          2.3  Iris-virginica
# 146           6.3          2.5           5.0          1.9  Iris-virginica
# 147           6.5          3.0           5.2          2.0  Iris-virginica
# 148           6.2          3.4           5.4          2.3  Iris-virginica
# 149           5.9          3.0           5.1          1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
#knowing data types 
f.dtypes
# Out:
# sepal_length    float64
# sepal_width     float64
# petal_length    float64
# petal_width     float64
# species          object
# dtype: object

# %%
f['species']
# Out:
# 0         Iris-setosa
# 1         Iris-setosa
# 2         Iris-setosa
# 3         Iris-setosa
# 4         Iris-setosa
#             ...
# 145    Iris-virginica
# 146    Iris-virginica
# 147    Iris-virginica
# 148    Iris-virginica
# 149    Iris-virginica
# Name: species, Length: 150, dtype: object

# %%
#knowing unique species
f['species'].unique()
# Out:
# array(['Iris-setosa', 'Iris-versicolor', 'Iris-virginica'], dtype=object)

# %%
#visualisation 
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(8, 6))
sns.scatterplot(x='sepal_length', y='sepal_width', data=f, hue='species', palette='Set1', s=100)
plt.title('Sepal Length vs Sepal Width')
plt.xlabel('Sepal Length')
plt.ylabel('Sepal Width')
plt.legend(loc='best')
plt.grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(8, 6))
sns.scatterplot(x='petal_length', y='petal_width', data=f, hue='species', palette='Set1', s=100)
plt.title('petal Length vs petal Width')
plt.xlabel('petal Length')
plt.ylabel('petal Width')
plt.legend(loc='best')
plt.grid(True)
plt.show()

# %%
#replacing categorical data with numeric values
f['species']=f['species'].replace({'Iris-setosa':1,'Iris-versicolor':2,'Iris-virginica':3})
f
# Out:
#      sepal_length  sepal_width  petal_length  petal_width  species
# 0             5.1          3.5           1.4          0.2        1
# 1             4.9          3.0           1.4          0.2        1
# 2             4.7          3.2           1.3          0.2        1
# 3             4.6          3.1           1.5          0.2        1
# 4             5.0          3.6           1.4          0.2        1
# ..            ...          ...           ...          ...      ...
# 145           6.7          3.0           5.2          2.3        3
# 146           6.3          2.5           5.0          1.9        3
# 147           6.5          3.0           5.2          2.0        3
# 148           6.2          3.4           5.4          2.3        3
# 149           5.9          3.0           5.1          1.8        3
#
# [150 rows x 5 columns]

# %%
#description about data
f.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width     species
# count    150.000000   150.000000    150.000000   150.000000  150.000000
# mean       5.843333     3.054000      3.758667     1.198667    2.000000
# std        0.828066     0.433594      1.764420     0.763161    0.819232
# min        4.300000     2.000000      1.000000     0.100000    1.000000
# 25%        5.100000     2.800000      1.600000     0.300000    1.000000
# 50%        5.800000     3.000000      4.350000     1.300000    2.000000
# 75%        6.400000     3.300000      5.100000     1.800000    3.000000
# max        7.900000     4.400000      6.900000     2.500000    3.000000

# %%
#building the model
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import train_test_split
x=f.drop(columns=['species'])
y=f['species']
xt,xtest,yt,ytest=train_test_split(x,y,test_size=0.2)
model=LogisticRegression(max_iter=1000)
model.fit(xt,yt)
# Out:
# LogisticRegression(max_iter=1000)

# %%
#making predictions
predict=model.predict(xtest)
predict
# Out:
# array([1, 3, 1, 1, 1, 3, 1, 3, 3, 3, 2, 1, 3, 1, 3, 1, 2, 1, 1, 2, 2, 3,
#        1, 1, 2, 2, 2, 3, 1, 3], dtype=int64)

# %%
#finding the accuracy of the model
from sklearn.metrics import accuracy_score
accur=accuracy_score(predict,ytest)
accur
# Out:
# 0.9333333333333333
